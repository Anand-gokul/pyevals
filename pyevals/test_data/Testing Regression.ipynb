# %%
import pandas as pd
from sklearn.model_selection import train_test_split as tts
import pyevals
data = pd.read_csv("Regression.csv")
data = data.drop("Unnamed: 0",axis=1)

# %%
data.head()
# Out:
#    SalePrice  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  \
# 0  12.247694    0.235294      0.75     0.418208  0.366344     1.0    1.0
# 1  12.109011    0.000000      0.75     0.495064  0.391317     1.0    1.0
# 2  12.317167    0.235294      0.75     0.434909  0.422359     1.0    1.0
# 3  11.849398    0.294118      0.75     0.388581  0.390295     1.0    1.0
# 4  12.429216    0.235294      0.75     0.513123  0.468761     1.0    1.0
#
#    LotShape  LandContour  Utilities  ...  Fence  MiscFeature  MiscVal  \
# 0  0.000000     0.333333        1.0  ...    1.0          1.0      0.0
# 1  0.000000     0.333333        1.0  ...    1.0          1.0      0.0
# 2  0.333333     0.333333        1.0  ...    1.0          1.0      0.0
# 3  0.333333     0.333333        1.0  ...    1.0          1.0      0.0
# 4  0.333333     0.333333        1.0  ...    1.0          1.0      0.0
#
#      MoSold  YrSold  SaleType  SaleCondition  LotFrontagenan  MasVnrAreanan  \
# ...

# %%
df = data.head(40)

# %%
a = pyevals.BuildPlots(df,['Alley','Street'],['SalePrice','LotFrontage'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-9ad711fad13d> in <module>
# ----> 1 a = pyevals.BuildPlots(df,['Alley','Street'],['SalePrice','LotFrontage'])
#
# ~/.local/lib/python3.6/site-packages/pyevals/__init__.py in __init__(self, data, CategoricalFeatures, ContinuousFeatures)
#      19         self.ContinuousFeatures = ContinuousFeatures
#      20
# ---> 21         Plots.MakePlots(self.data,self.CategoricalFeatures,self.ContinuousFeatures)
#      22
#      23 class build:
#
# ~/.local/lib/python3.6/site-packages/pyevals/Plots.py in MakePlots(df, cat_features, con_features)
#     155
#     156         # Pair Plot
# --> 157         a = sns.pairplot(df)
#     158         a.fig.suptitle('PairPlot :- ')
#     159         plt.savefig("PairPlot.pdf")
#
# ~/.local/lib/python3.6/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
# ...

# %%
y= data[['SalePrice']]
x=data.drop(['SalePrice'],axis=1)

# %%
x_train,x_test,y_train,y_test = tts(x,y,test_size=0.25,random_state=42)

# %%
a = pyevals.build(x_train,x_test,y_train,y_test,'regression')
a.evaluate()
# Out:
# <style  type="text/css" >
# #T_d9581b18_9e2d_11eb_afbd_8c705a151258row2_col0,#T_d9581b18_9e2d_11eb_afbd_8c705a151258row2_col1,#T_d9581b18_9e2d_11eb_afbd_8c705a151258row2_col3,#T_d9581b18_9e2d_11eb_afbd_8c705a151258row2_col4,#T_d9581b18_9e2d_11eb_afbd_8c705a151258row5_col2{
#             background-color:  yellow;
#         }</style><table id="T_d9581b18_9e2d_11eb_afbd_8c705a151258" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >1-R2Score</th>        <th class="col_heading level0 col1" >1-AdjustedR2</th>        <th class="col_heading level0 col2" >MeanAbsoluteError</th>        <th class="col_heading level0 col3" >MeanSquaredError</th>        <th class="col_heading level0 col4" >RootMeanSquaredError</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d9581b18_9e2d_11eb_afbd_8c705a151258level0_row0" class="row_heading level0 row0" >LinearRegression</th>
# ...

# %%
import seaborn as sns
import pyevals

tips = sns.load_dataset("tips")
tips.head()

# %%
pyevals.buildplot(tips,['smoker','day','time','size'],['total_bill'])

# %%
con_features=['total_bill','tip']

# %%
import matplotlib.pyplot as plt
    
def CalcuateRows(TotalPlots):
    if TotalPlots==3:
        return 1
    elif TotalPlots%3 == 0:
        return(int(TotalPlots/3))
    else:
        remainder = TotalPlots%3
        return(TotalPlots//3 + remainder)

# DistPlot 

TotalDistPlots = len(con_features)
f, axes = plt.subplots(CalcuateRows(TotalDistPlots), 3, figsize=(10,10))

column = 0
row = 0
while(row<TotalDistPlots):
    for i in con_features:
        if column<3:
            axes[row, column].set_title('DistPlot '+ i)
            sns.distplot(tips[i],ax=axes[row,column])	
            column+=1
        if column==3:
            row+=1
            column=0
    row+=1
plt.savefig("DistPlots.pdf")
plt.tight_layout()

# %%
import seaborn as sns
import pyevals

tips = sns.load_dataset("tips")
tips.head()
con_features=['total_bill']

# %%
df.head()

# %%
import pandas as pd
df = pd.read_csv('Regression.csv')
df.head()

# %%
df.head()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
    
def CalcuateRows(TotalPlots):
    if TotalPlots<=3:
        return 2
    elif TotalPlots%3 == 0:
        return(int(TotalPlots/3))
    else:
        return(TotalPlots//3 + 1)
    
# DistPlot 

TotalDistPlots = len(con_features)
f, axes = plt.subplots(CalcuateRows(TotalDistPlots),3,figsize=(10,10))

column = 0
row = 0

while(row<TotalDistPlots):
    for i in con_features:
        if column<3:
            try:
                sns.distplot(df[i],ax=axes[row,column])
                axes[row,column].set_title('DistPlot '+ i)
                column+=1
                if column==3:
                    row+=1
                    column=0
            except:
                print("",end="")
                
    row+=1
    
plt.savefig("DistPlots.pdf")
plt.tight_layout()

# %%
import pandas as pd
df = pd.read_csv('Regression.csv')
df.head()

# %%
f, axes = plt.subplots(1, 3,sharex=True, figsize=(10,10))
f.suptitle('Hello')
axes[0].set_title("Anand")

# %%
cat_features = ['Street']
con_features=['SalePrice','LotFrontage']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
    
def CalcuateRows(TotalPlots):
    if TotalPlots<=3:
        return 2
    elif TotalPlots%3 == 0:
        return(int(TotalPlots/3))
    else:
        return(TotalPlots//3 + 1)


TotalBarPlots = len(cat_features)
f, axes = plt.subplots(CalcuateRows(TotalBarPlots), 3, figsize=(10,10))

column = 0
row = 0

while(row<TotalBarPlots):
    for i in con_features:
        for j in cat_features:
                if column<3:
                    try:
                        axes[row, column].set_title('BarPlot '+ i + ' '+j)
                        sns.barplot(x=i,y=j,data=df,ax=axes[row,column])
                        column+=1
                        if column==3:
                            row+=1
                            column=0
                    except:
                        print("",end="")
    row+=1
plt.savefig("BarPlots.pdf")
plt.tight_layout()

# %%
import pyevals
import seaborn as sns

tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
pyevals.buildplot(tips,['sex','day','time'],['total_bill'])
